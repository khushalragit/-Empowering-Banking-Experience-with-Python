# %%
class Bank:
    def bank(self, menu, auth):
        print("Welcome to the bank")
        upin = int(input("Enter your pin: "))
        if auth.auth(upin):
            menu.menu(auth)
        else:
            print("Incorrect pin")

class Menu:
    def menu(self, auth):
        print("1. Withdraw")
        print("2. Deposit")
        print("3. Check Balance")
        print("4. Exit")
        choice = int(input("Enter your choice: "))
        if choice == 1:
            auth.withdraw()
        elif choice == 2:
            auth.deposit()
        elif choice == 3:
            auth.checkbalance()
        elif choice == 4:
            print("Thank you for using the bank")
        else:
            print("Incorrect choice")
            self.menu(auth)

class Withdraw:
    def withdraw(self, menu):
        withdraw = int(input("Enter the amount you want to withdraw: "))
        menu.balance -= withdraw
        print("Your new balance is", menu.balance)

class Deposit:
    def deposit(self, menu):
        deposit = int(input("Enter the amount you want to deposit: "))
        menu.balance += deposit
        print("You have deposited", deposit)
        print("Your new balance is", menu.balance)

class CheckBalance:
    def checkbalance(self, menu):
        print("Your balance is", menu.balance)

class Auth:
    def __init__(self):
        self.balance = 10000

    def auth(self, upin):
        pin = 1234
        return upin == pin

    def withdraw(self):
        w.withdraw(self)

    def deposit(self):
        d.deposit(self)

    def checkbalance(self):
        c.checkbalance(self)

c = CheckBalance()
d = Deposit()
w = Withdraw()
m = Menu()
b = Bank()
a = Auth()
b.bank(m, a)
# Out:
# Welcome to the bank
# Enter your pin:  1234
# 1. Withdraw
# 2. Deposit
# 3. Check Balance
# 4. Exit
# Enter your choice:  2
# Enter the amount you want to deposit:  100000
# You have deposited 100000
# Your new balance is 110000

# %%
balence = 10000
class Bank:
    def bank(self, auth,menu,withdraw):
        print("Welcome to the bank")
        upin = int(input("Enter your pin: "))
        if auth.auth(upin):
            m.menu(auth)
            w.withdraw(menu)
            d.deposit(menu)
            c.checkbalance(menu)
# oject call krk jis chiz ki need h wo yaha call hua h 
        else:
            print("Incorrect pin")
class Menu:
    def menu(self,auth):
      print("1. Withdraw")
      print("2. Deposit")
      print("3. Check  Balance")
      print("4. Exit")
      choice = int(input("Enter your choice: "))
      if choice == 1:
          w.withdraw()
        
      elif choice == 2:
          d.deposit()
      elif choice == 3:
          c.checkbalance()
      elif choice == 4:
        print("Thank you for using the bank")
      else:
        print("Incorrect choice")
        m.menu()
       

class Withdraw:
    def withdraw(self,menu):
      global balance
      withdraw = int(input("Enter the amount you want to withdraw: "))
      balance = balance - withdraw
      print("Your new balance is", balance)
      menu()

class Deposit:
    def deposit():
      global balance
      deposit = int(input("Enter the amount you want to deposit: "))
      balance = balance + deposit
      print("You have deposited", deposit)
      print("Your new balance is", balance)
      menu()

class  CheckBalance:
    def checkbalance():
      print("Your balance is", balance)
      menu()

class Auth:
    def auth(self, upin):
        pin = 1234
        return upin == pin
c = CheckBalance()
d = Deposit()
w = Withdraw()
m = Menu()
b = Bank()
a = Auth()
b.bank(a,m,w)

# %%
balance = 10000
class Bank:
    def bank(self, menu, auth):
        print("Welcome to the bank")
        upin = int(input("Enter your pin: "))
        if auth.auth(upin):
            menu.menu(auth)
            w.withdraw(menu)
            d.deposit()
            c.checkbalance()
        else:
            print("Incorrect pin")
class Menu:
    def menu(self, auth):
        print("1. Withdraw")
        print("2. Deposit")
        print("3. Check Balance")
        print("4. Exit")
        choice = int(input("Enter your choice: "))
        if choice == 1:
            w.withdraw()
        elif choice == 2:
            d.deposit()
        elif choice == 3:
            c.checkbalance()
        elif choice == 4:
            print("Thank you for using the bank")
        else:
            print("Incorrect choice")
            m.menu()
class Withdraw:
    def withdraw(self):
        global balance
        withdraw = int(input("Enter the amount you want to withdraw: "))
        balance = balance - withdraw
        print("Your new balance is", balance)
        menu()
class Deposit:
    def deposit(self):
        global balance
        deposit = int(input("Enter the amount you want to deposit: "))
        balance = balance + deposit
        print("You have deposited", deposit)
        print("Your new balance is", balance)
        menu()
class CheckBalance:
    def checkbalance(self):
        print("Your balance is", balance)
        menu()
class Auth:
    def auth(self, upin):
        pin = 1234
        return upin == pin
c = CheckBalance()
d = Deposit()
w = Withdraw()
m = Menu()
b = Bank()
a = Auth()
b.bank(m, a)
